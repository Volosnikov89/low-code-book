# %% [markdown]
# <a href="https://colab.research.google.com/github/Volosnikov89/low-code-book/blob/main/%22Chapter_2%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = 'https://data.cdc.gov/api/views/55yu-xksw/rows.csv?accessType=DOWNLOAD'
heart_df = pd.read_csv(url, index_col=0)

# %%
heart df.head
# Out:
#   File "<ipython-input-19-42bdf91afc4f>", line 1
#     heart df.head
#           ^
# SyntaxError: invalid syntax

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 78792 entries, 2020 to 2020
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LocationAbbr                78792 non-null  object
#  1   LocationDesc                78792 non-null  object
#  2   GeographicLevel             78792 non-null  object
#  3   DataSource                  78792 non-null  object
#  4   Class                       78792 non-null  object
#  5   Topic                       78792 non-null  object
#  6   Data_Value                  34430 non-null  float64
#  7   Data_Value_Unit             78792 non-null  object
#  8   Data_Value_Type             78792 non-null  object
#  9   Data_Value_Footnote_Symbol  44362 non-null  object
#  10  Data_Value_Footnote         44362 non-null  object
#  11  StratificationCategory1     78792 non-null  object
#  12  Stratification1             78792 non-null  object
# ...

# %%
heart_df = pd.read_csv('/content/heart.csv',engine="python")
heart_df.head()
# Out:
#    x  age sex   cp  trestbps chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  1   63   1  3.0       145  233  1.0        0      150      0      2.3
# 1  2   37   1  2.0       130  250  0.0        1      187      0      3.5
# 2  3   41   0  1.0       130  204  0.0        0      172      0      1.4
# 3  4   56   1  1.0       120  236  0.0        1      178      0      0.8
# 4  5   57   0  0.0       120  354  0.0        1      163      1      0.6
#
#    slope  ca  thal  target
# 0      0   0     1       1
# 1      0   0     2       1
# 2      2   0     2       1
# 3      2   0     2       1
# 4      2   0     2       1
